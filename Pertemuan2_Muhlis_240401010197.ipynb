# %% [markdown]
# <a href="https://colab.research.google.com/github/muhlis-id/Data-Science_240401010197_Muhlis/blob/main/Pertemuan2_Muhlis_240401010197.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Membuat List
data = [10, 20, 'Python', True, 3.14]

# Akses & Slicing
print(data[0])          # > 10
print(data[-1])         # > 3.14 (dari belakang)
print(data[1:3])        # > [20, 'Python']

#Manipulasi
data.append(99)         # Tambah di akhir
data.insert(1, 55)      # Sisipkan di posisi 1
data.remove(20)         # hapus nilai pertama = 20
#data.sort()             # urutkan (jika type sama)
# Out:
# 10
# 3.14
# [20, 'Python']
