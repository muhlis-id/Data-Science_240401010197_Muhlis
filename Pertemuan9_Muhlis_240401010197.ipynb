# %% [markdown]
# <a href="https://colab.research.google.com/github/muhlis-id/Data-Science_240401010197_Muhlis/blob/main/Pertemuan9_Muhlis_240401010197.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Pertemuan 9
#
# Nama: MUHLIS
# NIM: 240401010197
# Kelas: IF405

# %% [markdown]
# Kesimpulan
