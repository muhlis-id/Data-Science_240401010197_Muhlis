# %% [markdown]
# <a href="https://colab.research.google.com/github/muhlis-id/Data-Science_240401010197_Muhlis/blob/main/Pertemuan10_Muhlis_240401010197.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Pertemuan 10
#
# Nama: MUHLIS
# NIM: 240401010197
# Kelas: IF405

# %%
# ============================================
# Customer Churn
# ============================================

# %%
#Langkah 1: Muat dan Eksplorasi Data

import pandas as pd
df = pd.read_csv("telco_churn.csv")
print(df.shape)
print(df["Churn"].value_counts(normalize=True))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_2133/989773910.py in <cell line: 0>()
#       2
#       3 import pandas as pd
# ----> 4 df = pd.read_csv("telco_churn.csv")
#       5 print(df.shape)
#       6 print(df["Churn"].value_counts(normalize=True))
#
# ...

# %%
#Langkah 2: Preprocessing

from sklearn.model_selection import train_test_split
# TODO: encoding fitur kategorikal (mis. pd.get_dummies)
# TODO: pisahkan X (fitur) dan y (target = Churn)
X_tr, X_te, y_tr, y_te = train_test_split(
X, y, test_size=0.2, stratify=y, random_state=42)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_2133/4230770316.py in <cell line: 0>()
#       5 # TODO: pisahkan X (fitur) dan y (target = Churn)
#       6 X_tr, X_te, y_tr, y_te = train_test_split(
# ----> 7 X, y, test_size=0.2, stratify=y, random_state=42)
#
# NameError: name 'X' is not defined

# %%
#Langkah 3: Latih Model

from sklearn.ensemble import RandomForestClassifier
rf = RandomForestClassifier(
n_estimators=300, class_weight="balanced", random_state=42)
rf.fit(X_tr, y_tr)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_2133/2477735561.py in <cell line: 0>()
#       4 rf = RandomForestClassifier(
#       5 n_estimators=300, class_weight="balanced", random_state=42)
# ----> 6 rf.fit(X_tr, y_tr)
#
# NameError: name 'X_tr' is not defined

# %%
#Langkah 4: Evaluasi

from sklearn.metrics import classification_report, roc_auc_score
# TODO: hitung prediksi dan probabilitas
# TODO: tampilkan classification_report dan ROC-AUC

# %%
#Langkah 5: Prediksi Probabilitas dan Simpulkan

# TODO: hitung probabilitas churn (predict_proba)
# TODO: tulis kesimpulan singkat (3-4 kalimat)

# %% [markdown]
# Kesimpulan
# -
