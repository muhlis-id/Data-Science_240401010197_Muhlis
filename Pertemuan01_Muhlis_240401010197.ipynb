# %% [markdown]
# <a href="https://colab.research.google.com/github/muhlis-id/Data-Science_240401010197_Muhlis/blob/main/Pertemuan1_Muhlis_240401010197.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ================================
# Pertemuan 1 : Notebook Pertama Data Science
# =================================
#
# Nama: MUHLIS
# NIM: 240401010197
# Kelas: IF405

# %%
#SEL 1 : output sederhana
print("Hello World")
# Out:
# Hello World

# %%
#SEL 2 : Variable dan type data dasar
nama        = "muhlis" #string
angkatan    = 2024 #numerik
ipk         = 3.83 #Float
aktif       = True #Boolean

print(nama)
print(angkatan)
print(ipk)
print(aktif)
print(f"----------")
print(f"Hallo nama saya {nama} dari angkatan{angkatan} dengan ipk {ipk}")
# Out:
# muhlis
# 2024
# 3.83
# True
# ----------
# Hallo nama saya muhlis dari angkatan2024 dengan ipk 3.83

# %%
#SEL 3 : list dan perulangan
tools = ["Python", "Google colab", "Jupiter Notebook", 'Github']
print(tools[3])

#perulangan
for i in tools:
  print(i)

#print("\nTools Data Science yang akan kita pelajari:")
#for i, tool in enumerate(tools, 1):
#print(f" {i}. {tool}")
# Out:
# Github
# Python
# Google colab
# Jupiter Notebook
# Github

# %%
#SEL 4 : Fungsi
def perkenalan(nama, prodi, angkatan):
  return print(f"Hallo, nama saya {nama} dari prodi {prodi} angkatan {angkatan}")

perkenalan("Muhlis", "Informatika", 2024)
# Out:
# Hallo, nama saya Muhlis dari prodi Informatika angkatan 2024

# %% [markdown]
# Kesimpulan:
# Pada pertemuan pertama telah mempelajari Output sederhana, type data & variabel, list & perulangan dan fungsi.
