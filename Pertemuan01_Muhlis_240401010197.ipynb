# %% [markdown]
# <a href="https://colab.research.google.com/github/muhlis-id/Data-Science_240401010197_Muhlis/blob/main/Pertemuan01_Muhlis_240401010197.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ==============================================
# Pertemuan 1 : Notebook Pertama Data Science
#
# Nama: MUHLIS
# NIM: 240401010197
# Kelas: IF405

# %%
#output sederhana
print("Hello World")
# Out:
# Hello World

# %%
#Variable dan type data
nama = "muhlis" #string
angkatan = 2024 #numerik

print(nama)
print(angkatan)
print(f"Hallo nama saya {nama} dari angkatan{angkatan}")
# Out:
# muhlis
# 2024
# Hallo nama saya muhlis dari angkatan2024

# %%
#list
tools = ["Python", "Google colab", "Jupiter Notebook", 'Github']
print(tools[3])

#perulangan
for i in tools:
  print(i)
# Out:
# Github
# Python
# Google colab
# Jupiter Notebook
# Github

# %%
#Fungsi
def perkenalan(nama, prodi, angkatan):
  return print(f"Hallo, nama saya {nama} dari prodi {prodi} angkatan {angkatan}")

perkenalan("Muhlis", "Informatika", 2024)
# Out:
# Hallo, nama saya Muhlis dari prodi Informatika angkatan 2024

# %% [markdown]
# Kesimpulan: Pada pertemuan pertama telah mempelajari Output sederhana, type data & variabel, list & perulangan dan fungsi.
